# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# I am interested to get some visualisation diffarential equation. I am using **Vector Slope** method.

# %% [markdown]
# # Understand of `meshgrid`

# %%
x = np.linspace(-4, 4, 20)
y = np.linspace(-4, 4, 20)
X, Y = np.meshgrid(x,y)
plt.plot(X,Y, marker = '.', linestyle = 'none')
plt.show()

# %% [markdown]
# ## To Plot:: $\frac{dy}{dx}=\cos(x)$

# %%
dy = np.cos(X)
dx = np.ones(dy.shape)

#Plot
plt.quiver(X, Y, dy, dx)
plt.title("Vector plot of y'(x)")
plt.plot(x, np.sin(x))
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/matplotlib/_mathtext.py:2237, in Parser.parse(self, s, fonts_object, fontsize, dpi)
#    2236 try:
# -> 2237     result = self._expression.parseString(s)
#    2238 except ParseBaseException as err:
#
# File /usr/lib/python3/dist-packages/pyparsing.py:1955, in ParserElement.parseString(self, instring, parseAll)
#    1954             exc.__traceback__ = self._trim_traceback(exc.__traceback__)
# -> 1955         raise exc
#    1956 else:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/_mathtext.py:2395, in Parser.unknown_symbol(self, s, loc, toks)
#    2394 c, = toks
# -> 2395 raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#
# ParseFatalException: Unknown symbol: \displaystyle, found '\'  (at char 0), (line:1, col:1)
#
# ...

# %% [markdown]
# * Make the line unit. Only interested about **Direction**.

# %%
dyu = dy/np.sqrt(dx**2 + dy**2)
dxu = dx/np.sqrt(dx**2 + dy**2)
plt.quiver(X, Y, dyu, dxu)
plt.show()
